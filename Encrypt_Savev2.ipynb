# %%
import pandas as pd
from cryptography.fernet import Fernet
from csv import writer
from datetime import datetime

# %%
key = ''

def generate_key():
    """Generates a key and save it into a file"""
    key = Fernet.generate_key()
    with open("secret.key", "wb") as key_file:
        key_file.write(key)
        print("Key\n", key)
        
def load_key():
    """Load the previously generated key"""
    return open("secret.key", "rb").read()

def encrypt_message(message):
    """Encrypts a message"""
    key = load_key()
    encoded_message = message.encode()        
    f = Fernet(key)
    encrypted_message = f.encrypt(encoded_message)
    return encrypted_message

    
def decrypt_message(encrypt_message):
    """Decrypts an encrypted message"""
    key = load_key()
    f = Fernet(key)
    decrypted_message = f.decrypt(encrypt_message).decode()
    return decrypted_message

def log():
    date_time=datetime.now()
    timestamp= date_time.strftime("%d/%m/%Y-%H:%M")
    timestamp
    List= [timestamp, message, encrypt_message(message),key]
    with open('log1.csv', 'a') as f_object:
        writer_object = writer(f_object)
        writer_object.writerow(List)
        f_object.close()
    

flag = True
while flag == True:
    e_d = ["e", "d"]
    
    response_enc = input("\nDo you want to encrypt or decrypt a message? e or d: ")
    response_enc = response_enc.lower()
    if response_enc not in e_d:
        response_enc = input("\n!!!Please answer question!!! e or d: ")
        
    if response_enc == "e":
        message = input("ENTER message to ENCRYPT: ")
        generate_key()
        encrypt_message(message)
        print("\nENCRYPTING MESSAGE........\n", encrypt_message(message))
        break

    elif response_enc == "d":
        message = bytes(input("Select message to DECRYPT: "), "utf-8")
        load_key()
        decrypt_message(message)
        break
    else:
        print("you type 'n'... good bye.")
        break
    
 
    
    
flag = False
log()
# Out:
# Do you want to encrypt or decrypt a message? e or d: e
# ENTER message to ENCRYPT: hihi
# Key
#  b'PdfV09VrXiYtSCJqYwcvZnSZAJAq6DkQDAuUQWP0-70='
#
# ENCRYPTING MESSAGE........
#  b'gAAAAABgexY5QwgFAubz0H6Jl9hLQ8qmKn1XURKqdSIT9WryxNnECbJNsIq-78xKTgwhL6dD_vHPAjq6GDM6gRua6H1sxwpi6Q=='

# %%
Do you want to encrypt or decrypt a message? e or d: e
ENTER message to ENCRYPT: Pickles yeah
Key
 b'tQVpxjj2V9Re2whuyCv2PELSWwc7VrBG8lav5CDbDtA='

ENCRYPTING MESSAGE........
 b'gAAAAABgeuz_iLCSSOYmSwVKKodBwA-ZL5FqJUV7aSqWpje-EhAQf6gDIIDOSHwXAGv72MiVofQ24RBRor7ssB6Q5Mozpdo2mw=='
# Out:
#   File "<ipython-input-15-cc0c117302ea>", line 1
#     Do you want to encrypt or decrypt a message? e or d: e
#        ^
# SyntaxError: invalid syntax

# %%
pd.set_option('display.max_colwidth', None)


def read_log():
        read_log = pd.read_csv("log1.csv")
        read_log
        
read_log()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-24-6ebb88de2744> in <module>
#       6         read_log
#       7
# ----> 8 read_log()
#
# <ipython-input-24-6ebb88de2744> in read_log()
#       3
#       4 def read_log():
# ----> 5         read_log = pd.read_csv("log1.csv")
#       6         read_log
#       7
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     466
#     467     with parser:
# --> 468         return parser.read(nrows)
#     469
#     470
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1055     def read(self, nrows=None):
#    1056         nrows = validate_integer("nrows", nrows)
# -> 1057         index, columns, col_dict = self._engine.read(nrows)
#    1058
#    1059         if index is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2059     def read(self, nrows=None):
#    2060         try:
# -> 2061             data = self._reader.read(nrows)
#    2062         except StopIteration:
#    2063             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 3 fields in line 23, saw 4

# %%
read_log = pd.read_csv("log1.csv")
read_log
# Out:
#    17/04/2021-14:04           hi  \
# 0  17/04/2021-14:05           hi
# 1  17/04/2021-15:47           hi
# 2  17/04/2021-15:50           hi
# 3  17/04/2021-16:13            e
# 4  17/04/2021-16:13            d
# 5  17/04/2021-16:14            d
# 6  17/04/2021-16:14            d
# 7  17/04/2021-16:44           hi
# 8  17/04/2021-16:47           hi
# 9  17/04/2021-16:49  hello world
#
#    b'gAAAAABges7SXD-AFDWPXe_-2xIdeoPr_j6-1I-Rdp8N8XNaf-UlG1QxtBiDFssebyrEt5jBEGGUMyuNUh2m8qdtSkNtC9ydZA=='
# 0  b'gAAAAABges8aAdaX3J4WU4AFcyyZVjdEq9Q_1v8jT5wtDR8TGNH6-5UeEBW_FE85y23dgCmY80iIbg3crVnaDsOaZSAlRjmL7g=='
# 1  b'gAAAAABgeubXzKDVv1BxtVpWkjQl3BdMLJeH-6M87mA8UE6NzS0gbLhBtaqoz-1ksF3asRyFjcHJFtvdhfgwuv55GvPXWwSDZw=='
# 2  b'gAAAAABgeue2GqtA0Qk5kQPduzEloAGpdZbm6hSLXDvoeDlH0UwT16Y0Vpk2wCe2PUWUrsKbCa-pOMBlr9tCxaQr1IDJf5ohuQ=='
# 3  b'gAAAAABgeu0CNucdV0jsMtbTMxvOpuKi_xyDbHM66JSelvx0JyohdE_jOiS4KMqQtAnnaRSo-EypHR4U9eYvpMaEwuY_-Owy9Q=='
# 4  b'gAAAAABgeu0T2osoxKkALilw61TmQTC7KXJRyQqTlummV5UiMo3aRSGiK-GcSoLybYGB3qs-guYmUCoDQw6I3EBhR7wgg6NOoQ=='
# 5  b'gAAAAABgeu0wMIIEWy3EYGVRhUBAwuPV1xgoFc5JntxxuF5YMF18rVs8Zzuk4s5TS_07N5c5_OjGPUFwe06SCh6RVGDyDFnjQw=='
# 6  b'gAAAAABgeu1SYa7swhRwpCDeaBQONTWFBz5c7lzFkHcGmFZaSlQcOJ7WiCoVH-UPntKJkUGXZ0MwCBFJcsaTeYunvgPB1Nj9RA=='
# 7  b'gAAAAABgevRpd-J0KRmrmfHOacy63Mp5EaW6V_jMj61018q0G4lElFjXcO4I0rZIGpMkyYGhORJQHqqVUhZXnVjOhZx84kl-hQ=='
# 8  b'gAAAAABgevUZncUDI6mkdDl1Gh8flBYLultH-UNVz9F90qyh1tc4STW5YYeDo1ddDtrjVCAo1SMXvwv9qZNItsoh6fALFZ7y8g=='
# 9  b'gAAAAABgevWMgnzJ01G3_pWxGjddV6wlyKhECLGWjLwnC98Wd6Sm6dbO26JIaQ8CgNSX8sWYYgggURYlObEQuxV5s7BJGLXqlg=='
